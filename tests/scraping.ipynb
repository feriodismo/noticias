# %%
# !pip install bs4
from urllib.request import urlopen
from bs4 import BeautifulSoup as bs

# %%
# determinamos que pagina usar para scrapear
url = 'https://www.elchiguirebipolar.net/categoria/gente/'
# abro la pagina web
headers={'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/85.0.4183.102 Safari/537.36'}
page = urlopen(url)
page = bs(page, "html.parser")
print(page)
# Out:
# <!DOCTYPE html>
#
# <html class="no-js category-breves" lang="es">
# <head>
# <meta charset="utf-8"/>
# <link href="//fonts.googleapis.com" rel="dns-prefetch"/>
# <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
# <meta content="#DF5A24" name="theme-color"/>
# <link href="https://www.elchiguirebipolar.net/wp/wp-content/themes/chigui/img/logolindochigui.png" rel="icon" sizes="192x192"/>
# <title>Gente |  El Chigüire Bipolar</title>
# <link href="https://www.elchiguirebipolar.net/wp/wp-content/themes/chigui/css/foundation.min.css" rel="stylesheet"/>
# <link href="https://www.elchiguirebipolar.net/wp/wp-content/themes/chigui/micss.css" rel="stylesheet"/>
# <link href="http://gmpg.org/xfn/11" rel="profile"/>
# <link href="https://www.elchiguirebipolar.net/wp/xmlrpc.php" rel="pingback"/>
# <script src="https://www.elchiguirebipolar.net/wp/wp-content/themes/chigui/js/vendor/modernizr.js"></script>
# ...

# %%
import pandas as pd
articulo = page.findAll("article")
# print(articulo[0].figure.img['src'])
# print(articulo[11].figure.img['src'])
title, img, date, ctn, bot_enter = [],[],[],[],[] 

headers = ['title', 'img', 'date', 'ctn', 'bot_enter']
data = pd.DataFrame(columns=headers)
# print(s)
for art in articulo[:10]:
    title.append(art.h1.a.string)
    img.append(art.figure.img['src'])
    date.append(art.p.time.string)
    ctn.append(art.findAll("p")[1])
    bot_enter.append(art.findAll("a")[2]['href'])

data['title'] = title
data['img'] = img
data['date'] = date
data['ctn'] = ctn
data['bot_enter'] = bot_enter

c = data.to_csv('chi.csv', index=False)
# Out:
# Empty DataFrame
# Columns: [title, img, date, ctn, bot_enter]
# Index: []
